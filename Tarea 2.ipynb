# %% [markdown]
# # Tarea 2. La biblioteca `math`.
#
# El contenido de esta tarea no se encuentra directamente en ningún capítulo del libro. Por lo tanto en esta tarea la información se debe extraer de los vídeos adjuntos, así como de la documentación de la biblioteca `math`.
#
# Es recomendable importar la biblioteca `math` con la orden
# ```python
# import math
# ```
# y añadir siempre el prefijo `math.` a las funciones.
#
# Solamente hay que realizar 10 de los 12 ejercicios propuestos.

# %% [markdown]
# ### 1.- Razones trigonométricas en radianes.
#
#  Calcula las siguientes razones trigonométricas, expresadas en radianes.
# $$
# a)\, \cos(1) \qquad b)\, \sin\left(\frac{3\pi}{4}\right)
# $$

# %% [markdown]
# ### 2.- Razones trigonométricas en grados.
#
# Calcula las siguientes razones trigométricas, expresadas en grados (utiliza la función `radians()`).
#
# $$
# a)\, \tan(45) \qquad b)\, \arcsin(0.5)
# $$

# %% [markdown]
# ### 3.- Logaritmos en cualquier base.
#
# Calcula los siguientes logaritmos:
#
# $$
# a)\, \log_4(34.8) \qquad  b)\, \log_3(243)
# $$

# %% [markdown]
# ### 4.- La factorial y el logaritmo de la factorial.
#
#  Calcula la factorial de 70. Calcula después el logaritmo en base 10 del resultado anterior. Dicho número está relacionado con el número de cifras que tiene la factorial de 70. ¿Eres capaz de ver la relación entre el valor del logaritmo decimal y el número de cifras?

# %% [markdown]
# ### 5.- Conversión de radianes a grados.
#
# Convierte en grados los siguientes radianes. (Ayuda: estudia la documentación de la función `degrees()`).
#
# $$
# a)\, 3\,  rad \qquad b)\, \frac{\pi}{3} \, rad
# $$

# %% [markdown]
# ### 6.- Máximo común divisor.
#
# Calcula el máximo común denominador 5644 y 344. (Ayuda: consulta la documentación de las funciones `gcd()`).

# %% [markdown]
# ### 7.- Números combinatorios.
#
# Calcula el siguiente número combinatorio:
#
# $$
# \binom{34}{6}
# $$
#
# Os aconsejo mirar la ayuda del módulo `math`.

# %% [markdown]
# ### 8.- Un programa con la construcción `if else`.
#
# Crear un programa o función que nos pida un número entero y que devuelve las siguientes cadenas de texto:
#
# - Positivo.  Si el número es mayor que cero.
# - Negativo. Si el número es menor que cero.
# - Nulo. Si el número es el cero.

# %% [markdown]
# ### 9.- Cálculo de la hipotenusa.
#
# Si un triángulo rectángulo tiene catetos de medida 8 y 14 metros respectivamente, calcula, **en grados**, el ángulo menor de dicho triángulo. Guarda los valores de los catetos en variables, para así poder modificar el programa con otras medidas de los catetos.

# %% [markdown]
# ### 10.- Interés compuesto.
#
# Si ingreso 1000 euros en un banco que me ofrece un **interés compuesto** del 5% anual, calcula cuanto dinero tendré al cabo de 8 años. Guarda el capital inicial y el interes en variables para poder modificar el programa y adaptarlo a nuevos datos.

# %% [markdown]
# ### 11.- Operaciones con los números $e$ y $\pi$.
#
# Realiza los siguientes cálculos.
# $$
# a)\, e + \pi \qquad b)\, e^2 + \frac{\pi}{2}
# $$

# %% [markdown]
# ### 12.- Un problema con bucles.
#
# Crea un programa o función que calcule la factorial de los 10 primeros números pares (desde el 2 al 20). El programa debe imprimir cada factorial en una línea.
